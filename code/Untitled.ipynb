# %%
import numpy as np
import csv 
label = []
width = []
height = []
with open('window_stats.csv', 'rb') as f:
    reader = csv.reader(f)
    for row in reader:
        if row[0] != 'label':
            label.append(row[0])
#             print row[0]
        if row[1] != 'width':
#             print row[1]
            width.append(int(row[1]))
        if row[2] != 'height':
            height.append(int(row[2]))
            # print row[2]
# print label
# print widthprint width
# print height

# import matplotlib.pyplot
# import pylab

# matplotlib.pyplot.scatter(width, height, label=label)

# matplotlib.pyplot.show()
# print height

# import matplotlib.pyplot
# import pylab

# matplotlib.pyplot.scatter(width, height, label=label)
counter = 0
inc = [0]
print len(label)
for i in range (2, len(label)):
    if label[i] != label[i-1]:
        counter = counter + 1
    inc.append(counter)
    
print inc
print np.unique(label)
print len(np.unique(label))
# Out:
# 2823
# ...
